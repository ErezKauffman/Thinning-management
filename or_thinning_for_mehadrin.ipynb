# %% [markdown]
# thinning management for MEHADRIN

# %%
#pip install fpdf

# %%
from fpdf import FPDF
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_43352/4051462934.py in <module>
# ----> 1 from fpdf import FPDF
#
# ModuleNotFoundError: No module named 'fpdf'

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\tsede\OneDrive - FruitSpec\Nir Margalit - Fruit_growing\fruitspec\size estimation for customers\Israel\Mehadrin 2022')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_43352/1649809716.py in <module>
# ----> 1 df=pd.read_csv(r'C:\Users\tsede\OneDrive - FruitSpec\Nir Margalit - Fruit_growing\fruitspec\size estimation for customers\Israel\Mehadrin 2022')
#       2 df
#
# NameError: name 'pd' is not defined

# %%
#df_1st_measure=df[df["date"].isin(['2021-09-02','2021-08-25','2021-08-17'])]
#df_1st_measure

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
size_by_date= sns.boxplot(x= df["date"], y=df["size"],hue=df["name"])
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.gcf().set_size_inches(15, 8)
size_by_date= sns.swarmplot(x= df["date"], y=df["size"],hue=df["name"])
size_by_date
# Out:
# <AxesSubplot:xlabel='date', ylabel='size'>

# %%
#size_1st_date= sns.boxplot(x= df_1st_measure["date"], y=df_1st_measure["size"],hue=df_1st_measure["name"])
#size_1st_date

# %%
#data = [df.size["east"]]
#fig1, ax1 = plt.subplots()
#ax1.set_title('box_plot_size_by_date')
#ax1.boxplot([data])

#plt.show()
